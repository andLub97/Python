# %%
vendas = [1500, 2000, 4000,50]
meses = ['Jan','Fev','Mar','Abr']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(meses, vendas)
plt.ylabel('Vendas')
plt.xlabel('Meses')
plt.axis([0, 3, 0,5000])
plt.show()
